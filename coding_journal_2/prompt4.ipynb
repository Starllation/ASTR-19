# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
values = np.random.exponential(size=1000) # exponential distribution means smaller numbers common, larger ones rarer

histogram = plt.hist(values, bins=100, color='pink')
plt.xlabel('x')
plt.ylabel('y')

plt.savefig('prompt4_hist.pdf', bbox_inches='tight', dpi=600)
